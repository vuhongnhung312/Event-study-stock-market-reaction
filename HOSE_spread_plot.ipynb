# %%
import pandas as pd
import numpy as np

# %%
xls_CDNB = pd.ExcelFile(r'/Users/hongnhungvu/Desktop/Thesis_Data/CDNB_cleaned.xlsx')
df_NB = pd.read_excel(xls_CDNB)
xls_NLQ = pd.ExcelFile(r'/Users/hongnhungvu/Desktop/Thesis_Data/NLQ_cleaned.xlsx')
df_NLQ = pd.read_excel(xls_NLQ)
df_IT = df_NB.append(df_NLQ,ignore_index=True,sort=False)

# %%
df_IT = df_IT.drop(df_IT[(df_IT.RegisterBuyVolume.isnull())&(df_IT.BuyVolume == 0)].index)
df_IT = df_IT.drop(df_IT[(df_IT.RegisterSellVolume.isnull())&(df_IT.SellVolume == 0)].index)

# %%
xls_1220 = pd.ExcelFile('/Users/hongnhungvu/Desktop/Thesis_Data/Data_IT/Data_Trading_2012_2020.xlsx')
xls_11 = pd.ExcelFile('/Users/hongnhungvu/Desktop/Thesis_Data/Data_IT/Data_Trading_2011.xlsx')
xls_21 = pd.ExcelFile('/Users/hongnhungvu/Desktop/Thesis_Data/Data_IT/Data_Trading_2021.xlsx')

df1_1220 = pd.read_excel(xls_1220, '1')
df2_1220 = pd.read_excel(xls_1220, '2')
df3_1220 = pd.read_excel(xls_1220, '3')
df4_11 = pd.read_excel(xls_11)
df5_21 = pd.read_excel(xls_21)

#Merge all into df_1121
df_1121 = df1_1220.append([df2_1220,df3_1220,df4_11,df5_21],ignore_index=True,sort=False)
df_1121_dup = df_1121.copy()
df_1121_dup.rename(columns={"TradingDate":"RegisterDate"}, inplace=True)

# %%
#Map 'Exchange' & 'KLCPGD' values using cols
cols =['StockCode','RegisterDate']
df_IT['Exchange'] = df_IT.set_index(cols).index.map(df_1121_dup.set_index(cols)['Exchange'])
df_IT['KLCPLH'] = df_IT.set_index(cols).index.map(df_1121_dup.set_index(cols)['KLCPLH'])

#Calculate date difference
from datetime import datetime
T0 = [d.date() for d in df_IT['RegisterDate']]
T1 = [d.date() for d in df_IT['DateStartExpected']]
T2 = [d.date() for d in df_IT['DateEndExpected']]
df_IT['Diff_days_T0_T1'] = np.busday_count(T0, T1)
df_IT['Diff_days_T1_T2'] = np.busday_count(T1, T2)

#Recalculate percentage values
df_IT['RegisterVolumeBeforePercent'] = df_IT['RegisterVolumeBefore']/df_IT['KLCPLH']
df_IT['RegisterVolumeAfterPercent'] = df_IT['RegisterVolumeAfter']/df_IT['KLCPLH']
df_IT['VolumeBeforePercent'] = df_IT['VolumeBefore']/df_IT['KLCPLH']
df_IT['VolumeAfterPercent'] = df_IT['VolumeAfter']/df_IT['KLCPLH']

#Cleaning data: drop all percentage values>1
df_IT = df_IT[(df_IT['RegisterVolumeBeforePercent'] < 1) &
               (df_IT['RegisterVolumeAfterPercent'] < 1) &
               (df_IT['VolumeBeforePercent'] < 1) & (df_IT['VolumeAfterPercent']<1)]

# %%
df_1121_dup['Percentage_quoted_spread']=(df_1121_dup['BestSell']-df_1121_dup['BestBuy'])/((df_1121_dup['BestBuy']+df_1121_dup['BestSell'])/2)

# %%
df_1121_dup = df_1121_dup.drop(df_1121_dup[df_1121_dup.BestBuy == 0].index)
df_1121_dup = df_1121_dup.drop(df_1121_dup[df_1121_dup.BestSell == 0].index)
df_1121_dup
# Out:
#         StockCode Exchange TodayEx RegisterDate  OpenPrice  ClosePrice  \
# 0             A32    UPCOM   UPCOM   2020-12-31      34500       34500
# 3             A32    UPCOM   UPCOM   2020-12-28      34600       35000
# 6             A32    UPCOM   UPCOM   2020-12-23      34500       34500
# 7             A32    UPCOM   UPCOM   2020-12-22      34500       34500
# 8             A32    UPCOM   UPCOM   2020-12-21      30000       30000
# ...           ...      ...     ...          ...        ...         ...
# 2570739       YEG     HOSE    HOSE   2021-01-08      46400       46000
# 2570740       YEG     HOSE    HOSE   2021-01-07      46400       46700
# 2570741       YEG     HOSE    HOSE   2021-01-06      46400       46400
# 2570742       YEG     HOSE    HOSE   2021-01-05      46800       46400
# 2570743       YEG     HOSE    HOSE   2021-01-04      46100       46800
#
#           CloseAdj  BestBuy  BestSell  TotalVol    TotalVal    KLCPLH  \
# ...

# %%
df_IT = df_IT.drop(df_IT[df_IT.Diff_days_T1_T2 >= 46].index)

# %%
#Match spread
df_IT_VNI = df_IT[df_IT['Exchange']=='HOSE'].copy()

cols =['StockCode','RegisterDate']
for x in range(-30,0):
    df_IT_VNI['Spread_' + str(x)] = df_IT_VNI.set_index(cols).index.map(df_1121_dup.set_index(cols)['Percentage_quoted_spread'].shift(x))

df_IT_VNI['Spread_0'] = df_IT_VNI.set_index(cols).index.map(df_1121_dup.set_index(cols)['Percentage_quoted_spread'])

for x in range(1,36):
    df_IT_VNI['Spread_' + str(x)] = df_IT_VNI.set_index(cols).index.map(df_1121_dup.set_index(cols)['Percentage_quoted_spread'].shift(x))

# %%
df_VNI_buy = pd.DataFrame(df_IT_VNI[(df_IT_VNI['RegisterSellVolume'].isnull())])
df_VNI_sell = pd.DataFrame(df_IT_VNI[(df_IT_VNI['RegisterBuyVolume'].isnull())])

# %%
df_spread_buy_VNI = df_VNI_buy.iloc[:,34:100].copy()
df_spread_buy_VNI.columns = np.arange(-30,36)

df_spread_sell_VNI = df_VNI_sell.iloc[:,34:100].copy()
df_spread_sell_VNI.columns = np.arange(-30,36)

#df_VNI_buy.columns.get_indexer(['Spread_-30', 'Spread_35'])
#array([34, 99])

# %%
df_spread_buy_VNI['Period_length_T0_T1']= df_VNI_buy['Diff_days_T0_T1'].values
df_spread_sell_VNI['Period_length_T0_T1']= df_VNI_sell['Diff_days_T0_T1'].values

# %%
df_spread_buy_VNI_2345 = df_spread_buy_VNI[(df_spread_buy_VNI['Period_length_T0_T1']<=5)&(df_spread_buy_VNI['Period_length_T0_T1']>=2)]

df_spread_buy_VNI_2345corrected = pd.DataFrame(df_spread_buy_VNI_2345.set_index('Period_length_T0_T1').stack())
df_spread_buy_VNI_2345corrected.index.set_names('Day', level=len(df_spread_buy_VNI_2345corrected.index.names)-1, inplace=True)
df_spread_buy_VNI_2345corrected.columns = ['Percentage Quoted Spread']

df_spread_sell_VNI_2345 = df_spread_sell_VNI[(df_spread_sell_VNI['Period_length_T0_T1']<=5)&(df_spread_sell_VNI['Period_length_T0_T1']>=2)]

df_spread_sell_VNI_2345corrected = pd.DataFrame(df_spread_sell_VNI_2345.set_index('Period_length_T0_T1').stack())
df_spread_sell_VNI_2345corrected.index.set_names('Day', level=len(df_spread_sell_VNI_2345corrected.index.names)-1, inplace=True)
df_spread_sell_VNI_2345corrected.columns = ['Percentage Quoted Spread']

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="darkgrid")
sns.set(rc={"figure.figsize": (8, 8)})
plt.rcParams['figure.dpi'] = 360

# %%
Spread_buy_VNI = sns.lineplot(data=df_spread_buy_VNI_2345corrected, x="Day", y="Percentage Quoted Spread",hue="Period_length_T0_T1",ci=90,palette ="bone")
Spread_buy_VNI.set(title='HOSE_Buy announcement')
Spread_buy_VNI.set(ylim=(-0.025, 0.025))
plt.savefig("Spread_buy_VNI.png")

# %%
Spread_sell_VNI = sns.lineplot(data=df_spread_sell_VNI_2345corrected, x="Day", y="Percentage Quoted Spread",hue="Period_length_T0_T1",ci=90,palette ="bone")
Spread_sell_VNI.set(title='HOSE_Sell announcement')
Spread_sell_VNI.set(ylim=(-0.025, 0.025))
plt.savefig("Spread_sell_VNI.png")
